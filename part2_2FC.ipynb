# %%
# !unzip images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/validation/Class 1 Touch/82247.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82247.jpg
#   inflating: images/validation/Class 1 Touch/85500.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85500.jpg
#   inflating: images/validation/Class 1 Touch/85266.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85266.jpg
#   inflating: images/validation/Class 1 Touch/85272.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85272.jpg
#   inflating: images/validation/Class 1 Touch/85514.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85514.jpg
#   inflating: images/validation/Class 1 Touch/82290.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82290.jpg
#   inflating: images/validation/Class 1 Touch/228.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._228.jpg
#   inflating: images/validation/Class 1 Touch/85299.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85299.jpg
#   inflating: images/validation/Class 1 Touch/82284.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82284.jpg
#   inflating: images/validation/Class 1 Touch/214.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._214.jpg
#   inflating: images/validation/Class 1 Touch/572.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._572.jpg
#   inflating: images/validation/Class 1 Touch/566.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._566.jpg
#   inflating: images/validation/Class 1 Touch/200.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._200.jpg
#   inflating: images/validation/Class 1 Touch/957.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._957.jpg
#   inflating: images/validation/Class 1 Touch/943.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._943.jpg
#   inflating: images/validation/Class 1 Touch/758.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._758.jpg
#   inflating: images/validation/Class 1 Touch/980.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._980.jpg
#   inflating: images/validation/Class 1 Touch/770.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._770.jpg
#   inflating: images/validation/Class 1 Touch/764.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._764.jpg
#   inflating: images/validation/Class 1 Touch/765.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._765.jpg
#   inflating: images/validation/Class 1 Touch/771.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._771.jpg
#   inflating: images/validation/Class 1 Touch/981.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._981.jpg
#   inflating: images/validation/Class 1 Touch/759.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._759.jpg
#   inflating: images/validation/Class 1 Touch/942.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._942.jpg
#   inflating: images/validation/Class 1 Touch/956.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._956.jpg
#   inflating: images/validation/Class 1 Touch/567.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._567.jpg
#   inflating: images/validation/Class 1 Touch/201.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._201.jpg
#   inflating: images/validation/Class 1 Touch/215.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._215.jpg
#   inflating: images/validation/Class 1 Touch/573.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._573.jpg
#   inflating: images/validation/Class 1 Touch/82285.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82285.jpg
#   inflating: images/validation/Class 1 Touch/229.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._229.jpg
#   inflating: images/validation/Class 1 Touch/82291.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82291.jpg
#   inflating: images/validation/Class 1 Touch/85298.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85298.jpg
#   inflating: images/validation/Class 1 Touch/85273.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85273.jpg
#   inflating: images/validation/Class 1 Touch/85515.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85515.jpg
#   inflating: images/validation/Class 1 Touch/85501.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85501.jpg
#   inflating: images/validation/Class 1 Touch/85267.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85267.jpg
#   inflating: images/validation/Class 1 Touch/598.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._598.jpg
#   inflating: images/validation/Class 1 Touch/82246.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82246.jpg
#   inflating: images/validation/Class 1 Touch/85529.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85529.jpg
#   inflating: images/validation/Class 1 Touch/82252.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82252.jpg
#   inflating: images/validation/Class 1 Touch/85307.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85307.jpg
#   inflating: images/validation/Class 1 Touch/85461.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85461.jpg
#   inflating: images/validation/Class 1 Touch/85313.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85313.jpg
#   inflating: images/validation/Class 1 Touch/85449.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85449.jpg
#   inflating: images/validation/Class 1 Touch/177.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._177.jpg
#   inflating: images/validation/Class 1 Touch/611.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._611.jpg
#   inflating: images/validation/Class 1 Touch/89.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._89.jpg
#   inflating: images/validation/Class 1 Touch/605.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._605.jpg
#   inflating: images/validation/Class 1 Touch/163.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._163.jpg
#   inflating: images/validation/Class 1 Touch/639.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._639.jpg
#   inflating: images/validation/Class 1 Touch/188.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._188.jpg
#   inflating: images/validation/Class 1 Touch/836.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._836.jpg
#   inflating: images/validation/Class 1 Touch/76.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._76.jpg
#   inflating: images/validation/Class 1 Touch/822.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._822.jpg
#   inflating: images/validation/Class 1 Touch/62.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._62.jpg
#   inflating: images/validation/Class 1 Touch/74.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._74.jpg
#   inflating: images/validation/Class 1 Touch/834.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._834.jpg
#   inflating: images/validation/Class 1 Touch/85649.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85649.jpg
#   inflating: images/validation/Class 1 Touch/60.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._60.jpg
#   inflating: images/validation/Class 1 Touch/820.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._820.jpg
#   inflating: images/validation/Class 1 Touch/48.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._48.jpg
#   inflating: images/validation/Class 1 Touch/808.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._808.jpg
#   inflating: images/validation/Class 1 Touch/149.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._149.jpg
#   inflating: images/validation/Class 1 Touch/613.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._613.jpg
#   inflating: images/validation/Class 1 Touch/175.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._175.jpg
#   inflating: images/validation/Class 1 Touch/161.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._161.jpg
#   inflating: images/validation/Class 1 Touch/607.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._607.jpg
#   inflating: images/validation/Class 1 Touch/85339.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85339.jpg
#   inflating: images/validation/Class 1 Touch/85463.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85463.jpg
#   inflating: images/validation/Class 1 Touch/85305.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85305.jpg
#   inflating: images/validation/Class 1 Touch/85311.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85311.jpg
#   inflating: images/validation/Class 1 Touch/85477.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85477.jpg
#   inflating: images/validation/Class 1 Touch/85488.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85488.jpg
#   inflating: images/validation/Class 1 Touch/82244.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82244.jpg
#   inflating: images/validation/Class 1 Touch/85259.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85259.jpg
#   inflating: images/validation/Class 1 Touch/82250.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82250.jpg
#   inflating: images/validation/Class 1 Touch/85517.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85517.jpg
#   inflating: images/validation/Class 1 Touch/82278.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82278.jpg
#   inflating: images/validation/Class 1 Touch/85271.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85271.jpg
#   inflating: images/validation/Class 1 Touch/85265.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85265.jpg
#   inflating: images/validation/Class 1 Touch/85503.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85503.jpg
#   inflating: images/validation/Class 1 Touch/82287.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82287.jpg
#   inflating: images/validation/Class 1 Touch/559.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._559.jpg
#   inflating: images/validation/Class 1 Touch/82293.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82293.jpg
#   inflating: images/validation/Class 1 Touch/203.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._203.jpg
#   inflating: images/validation/Class 1 Touch/565.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._565.jpg
#   inflating: images/validation/Class 1 Touch/571.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._571.jpg
#   inflating: images/validation/Class 1 Touch/217.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._217.jpg
#   inflating: images/validation/Class 1 Touch/940.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._940.jpg
#   inflating: images/validation/Class 1 Touch/798.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._798.jpg
#   inflating: images/validation/Class 1 Touch/954.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._954.jpg
#   inflating: images/validation/Class 1 Touch/968.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._968.jpg
#   inflating: images/validation/Class 1 Touch/983.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._983.jpg
#   inflating: images/validation/Class 1 Touch/767.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._767.jpg
#   inflating: images/validation/Class 1 Touch/773.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._773.jpg
#   inflating: images/validation/Class 1 Touch/772.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._772.jpg
#   inflating: images/validation/Class 1 Touch/766.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._766.jpg
#   inflating: images/validation/Class 1 Touch/982.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._982.jpg
#   inflating: images/validation/Class 1 Touch/969.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._969.jpg
#   inflating: images/validation/Class 1 Touch/955.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._955.jpg
#   inflating: images/validation/Class 1 Touch/799.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._799.jpg
#   inflating: images/validation/Class 1 Touch/941.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._941.jpg
#   inflating: images/validation/Class 1 Touch/570.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._570.jpg
#   inflating: images/validation/Class 1 Touch/216.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._216.jpg
#   inflating: images/validation/Class 1 Touch/202.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._202.jpg
#   inflating: images/validation/Class 1 Touch/564.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._564.jpg
#   inflating: images/validation/Class 1 Touch/82292.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82292.jpg
#   inflating: images/validation/Class 1 Touch/82286.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82286.jpg
#   inflating: images/validation/Class 1 Touch/558.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._558.jpg
#   inflating: images/validation/Class 1 Touch/85264.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85264.jpg
#   inflating: images/validation/Class 1 Touch/85502.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85502.jpg
#   inflating: images/validation/Class 1 Touch/82279.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82279.jpg
#   inflating: images/validation/Class 1 Touch/85516.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85516.jpg
#   inflating: images/validation/Class 1 Touch/85270.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85270.jpg
#   inflating: images/validation/Class 1 Touch/85258.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85258.jpg
#   inflating: images/validation/Class 1 Touch/82251.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82251.jpg
#   inflating: images/validation/Class 1 Touch/82245.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82245.jpg
#   inflating: images/validation/Class 1 Touch/85489.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85489.jpg
#   inflating: images/validation/Class 1 Touch/85310.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85310.jpg
#   inflating: images/validation/Class 1 Touch/85476.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85476.jpg
#   inflating: images/validation/Class 1 Touch/85462.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85462.jpg
#   inflating: images/validation/Class 1 Touch/85304.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85304.jpg
#   inflating: images/validation/Class 1 Touch/85338.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85338.jpg
#   inflating: images/validation/Class 1 Touch/160.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._160.jpg
#   inflating: images/validation/Class 1 Touch/606.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._606.jpg
#   inflating: images/validation/Class 1 Touch/612.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._612.jpg
#   inflating: images/validation/Class 1 Touch/174.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._174.jpg
#   inflating: images/validation/Class 1 Touch/148.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._148.jpg
#   inflating: images/validation/Class 1 Touch/809.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._809.jpg
#   inflating: images/validation/Class 1 Touch/49.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._49.jpg
#   inflating: images/validation/Class 1 Touch/85648.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85648.jpg
#   inflating: images/validation/Class 1 Touch/821.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._821.jpg
#   inflating: images/validation/Class 1 Touch/61.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._61.jpg
#   inflating: images/validation/Class 1 Touch/835.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._835.jpg
#   inflating: images/validation/Class 1 Touch/75.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._75.jpg
#   inflating: images/validation/Class 1 Touch/59.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._59.jpg
#   inflating: images/validation/Class 1 Touch/819.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._819.jpg
#   inflating: images/validation/Class 1 Touch/71.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._71.jpg
#   inflating: images/validation/Class 1 Touch/831.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._831.jpg
#   inflating: images/validation/Class 1 Touch/65.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._65.jpg
#   inflating: images/validation/Class 1 Touch/825.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._825.jpg
#   inflating: images/validation/Class 1 Touch/170.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._170.jpg
#   inflating: images/validation/Class 1 Touch/616.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._616.jpg
#   inflating: images/validation/Class 1 Touch/602.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._602.jpg
#   inflating: images/validation/Class 1 Touch/164.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._164.jpg
#   inflating: images/validation/Class 1 Touch/158.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._158.jpg
#   inflating: images/validation/Class 1 Touch/85300.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85300.jpg
#   inflating: images/validation/Class 1 Touch/85466.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85466.jpg
#   inflating: images/validation/Class 1 Touch/82309.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82309.jpg
#   inflating: images/validation/Class 1 Touch/85314.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85314.jpg
#   inflating: images/validation/Class 1 Touch/85328.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85328.jpg
#   inflating: images/validation/Class 1 Touch/85499.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85499.jpg
#   inflating: images/validation/Class 1 Touch/85274.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85274.jpg
#   inflating: images/validation/Class 1 Touch/85512.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85512.jpg
#   inflating: images/validation/Class 1 Touch/82269.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82269.jpg
#   inflating: images/validation/Class 1 Touch/85506.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85506.jpg
#   inflating: images/validation/Class 1 Touch/85260.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85260.jpg
#   inflating: images/validation/Class 1 Touch/85248.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85248.jpg
#   inflating: images/validation/Class 1 Touch/82241.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82241.jpg
#   inflating: images/validation/Class 1 Touch/82255.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82255.jpg
#   inflating: images/validation/Class 1 Touch/560.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._560.jpg
#   inflating: images/validation/Class 1 Touch/206.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._206.jpg
#   inflating: images/validation/Class 1 Touch/212.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._212.jpg
#   inflating: images/validation/Class 1 Touch/574.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._574.jpg
#   inflating: images/validation/Class 1 Touch/82282.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82282.jpg
#   inflating: images/validation/Class 1 Touch/82296.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82296.jpg
#   inflating: images/validation/Class 1 Touch/548.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._548.jpg
#   inflating: images/validation/Class 1 Touch/979.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._979.jpg
#   inflating: images/validation/Class 1 Touch/945.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._945.jpg
#   inflating: images/validation/Class 1 Touch/951.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._951.jpg
#   inflating: images/validation/Class 1 Touch/789.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._789.jpg
#   inflating: images/validation/Class 1 Touch/762.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._762.jpg
#   inflating: images/validation/Class 1 Touch/776.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._776.jpg
#   inflating: images/validation/Class 1 Touch/986.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._986.jpg
#   inflating: images/validation/Class 1 Touch/987.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._987.jpg
#   inflating: images/validation/Class 1 Touch/777.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._777.jpg
#   inflating: images/validation/Class 1 Touch/763.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._763.jpg
#   inflating: images/validation/Class 1 Touch/788.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._788.jpg
#   inflating: images/validation/Class 1 Touch/950.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._950.jpg
#   inflating: images/validation/Class 1 Touch/944.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._944.jpg
#   inflating: images/validation/Class 1 Touch/978.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._978.jpg
#   inflating: images/validation/Class 1 Touch/82297.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82297.jpg
#   inflating: images/validation/Class 1 Touch/549.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._549.jpg
#   inflating: images/validation/Class 1 Touch/82283.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82283.jpg
#   inflating: images/validation/Class 1 Touch/213.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._213.jpg
#   inflating: images/validation/Class 1 Touch/575.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._575.jpg
#   inflating: images/validation/Class 1 Touch/561.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._561.jpg
#   inflating: images/validation/Class 1 Touch/207.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._207.jpg
#   inflating: images/validation/Class 1 Touch/82254.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82254.jpg
#   inflating: images/validation/Class 1 Touch/85249.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85249.jpg
#   inflating: images/validation/Class 1 Touch/82240.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82240.jpg
#   inflating: images/validation/Class 1 Touch/85507.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85507.jpg
#   inflating: images/validation/Class 1 Touch/82268.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82268.jpg
#   inflating: images/validation/Class 1 Touch/85261.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85261.jpg
#   inflating: images/validation/Class 1 Touch/85275.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85275.jpg
#   inflating: images/validation/Class 1 Touch/85513.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85513.jpg
#   inflating: images/validation/Class 1 Touch/85498.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85498.jpg
#   inflating: images/validation/Class 1 Touch/85329.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85329.jpg
#   inflating: images/validation/Class 1 Touch/85315.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85315.jpg
#   inflating: images/validation/Class 1 Touch/85301.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85301.jpg
#   inflating: images/validation/Class 1 Touch/82308.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82308.jpg
#   inflating: images/validation/Class 1 Touch/85467.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85467.jpg
#   inflating: images/validation/Class 1 Touch/159.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._159.jpg
#   inflating: images/validation/Class 1 Touch/603.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._603.jpg
#   inflating: images/validation/Class 1 Touch/165.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._165.jpg
#   inflating: images/validation/Class 1 Touch/171.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._171.jpg
#   inflating: images/validation/Class 1 Touch/617.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._617.jpg
#   inflating: images/validation/Class 1 Touch/824.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._824.jpg
#   inflating: images/validation/Class 1 Touch/64.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._64.jpg
#   inflating: images/validation/Class 1 Touch/830.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._830.jpg
#   inflating: images/validation/Class 1 Touch/70.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._70.jpg
#   inflating: images/validation/Class 1 Touch/818.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._818.jpg
#   inflating: images/validation/Class 1 Touch/58.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._58.jpg
#   inflating: images/validation/Class 1 Touch/198.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._198.jpg
#   inflating: images/validation/Class 1 Touch/66.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._66.jpg
#   inflating: images/validation/Class 1 Touch/826.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._826.jpg
#   inflating: images/validation/Class 1 Touch/72.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._72.jpg
#   inflating: images/validation/Class 1 Touch/832.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._832.jpg
#   inflating: images/validation/Class 1 Touch/167.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._167.jpg
#   inflating: images/validation/Class 1 Touch/601.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._601.jpg
#   inflating: images/validation/Class 1 Touch/99.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._99.jpg
#   inflating: images/validation/Class 1 Touch/615.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._615.jpg
#   inflating: images/validation/Class 1 Touch/173.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._173.jpg
#   inflating: images/validation/Class 1 Touch/629.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._629.jpg
#   inflating: images/validation/Class 1 Touch/85317.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85317.jpg
#   inflating: images/validation/Class 1 Touch/85471.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85471.jpg
#   inflating: images/validation/Class 1 Touch/85465.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85465.jpg
#   inflating: images/validation/Class 1 Touch/85303.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85303.jpg
#   inflating: images/validation/Class 1 Touch/85459.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85459.jpg
#   inflating: images/validation/Class 1 Touch/85263.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85263.jpg
#   inflating: images/validation/Class 1 Touch/85505.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85505.jpg
#   inflating: images/validation/Class 1 Touch/85511.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85511.jpg
#   inflating: images/validation/Class 1 Touch/85277.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85277.jpg
#   inflating: images/validation/Class 1 Touch/588.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._588.jpg
#   inflating: images/validation/Class 1 Touch/82256.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82256.jpg
#   inflating: images/validation/Class 1 Touch/85539.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85539.jpg
#   inflating: images/validation/Class 1 Touch/82242.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82242.jpg
#   inflating: images/validation/Class 1 Touch/577.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._577.jpg
#   inflating: images/validation/Class 1 Touch/211.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._211.jpg
#   inflating: images/validation/Class 1 Touch/205.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._205.jpg
#   inflating: images/validation/Class 1 Touch/563.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._563.jpg
#   inflating: images/validation/Class 1 Touch/82295.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82295.jpg
#   inflating: images/validation/Class 1 Touch/239.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._239.jpg
#   inflating: images/validation/Class 1 Touch/82281.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82281.jpg
#   inflating: images/validation/Class 1 Touch/85288.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85288.jpg
#   inflating: images/validation/Class 1 Touch/952.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._952.jpg
#   inflating: images/validation/Class 1 Touch/946.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._946.jpg
#   inflating: images/validation/Class 1 Touch/775.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._775.jpg
#   inflating: images/validation/Class 1 Touch/761.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._761.jpg
#   inflating: images/validation/Class 1 Touch/749.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._749.jpg
#   inflating: images/validation/Class 1 Touch/991.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._991.jpg
#   inflating: images/validation/Class 1 Touch/985.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._985.jpg
#   inflating: images/validation/Class 1 Touch/984.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._984.jpg
#   inflating: images/validation/Class 1 Touch/990.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._990.jpg
#   inflating: images/validation/Class 1 Touch/748.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._748.jpg
#   inflating: images/validation/Class 1 Touch/760.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._760.jpg
#   inflating: images/validation/Class 1 Touch/774.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._774.jpg
#   inflating: images/validation/Class 1 Touch/947.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._947.jpg
#   inflating: images/validation/Class 1 Touch/953.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._953.jpg
#   inflating: images/validation/Class 1 Touch/82280.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82280.jpg
#   inflating: images/validation/Class 1 Touch/238.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._238.jpg
#   inflating: images/validation/Class 1 Touch/85289.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85289.jpg
#   inflating: images/validation/Class 1 Touch/82294.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82294.jpg
#   inflating: images/validation/Class 1 Touch/204.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._204.jpg
#   inflating: images/validation/Class 1 Touch/562.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._562.jpg
#   inflating: images/validation/Class 1 Touch/576.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._576.jpg
#   inflating: images/validation/Class 1 Touch/210.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._210.jpg
#   inflating: images/validation/Class 1 Touch/82243.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82243.jpg
#   inflating: images/validation/Class 1 Touch/589.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._589.jpg
#   inflating: images/validation/Class 1 Touch/85538.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85538.jpg
#   inflating: images/validation/Class 1 Touch/82257.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82257.jpg
#   inflating: images/validation/Class 1 Touch/85510.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85510.jpg
#   inflating: images/validation/Class 1 Touch/85276.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85276.jpg
#   inflating: images/validation/Class 1 Touch/85262.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85262.jpg
#   inflating: images/validation/Class 1 Touch/85504.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85504.jpg
#   inflating: images/validation/Class 1 Touch/85458.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85458.jpg
#   inflating: images/validation/Class 1 Touch/85464.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85464.jpg
#   inflating: images/validation/Class 1 Touch/85302.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85302.jpg
#   inflating: images/validation/Class 1 Touch/85316.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85316.jpg
#   inflating: images/validation/Class 1 Touch/85470.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85470.jpg
#   inflating: images/validation/Class 1 Touch/628.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._628.jpg
#   inflating: images/validation/Class 1 Touch/614.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._614.jpg
#   inflating: images/validation/Class 1 Touch/172.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._172.jpg
#   inflating: images/validation/Class 1 Touch/166.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._166.jpg
#   inflating: images/validation/Class 1 Touch/98.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._98.jpg
#   inflating: images/validation/Class 1 Touch/600.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._600.jpg
#   inflating: images/validation/Class 1 Touch/833.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._833.jpg
#   inflating: images/validation/Class 1 Touch/73.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._73.jpg
#   inflating: images/validation/Class 1 Touch/199.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._199.jpg
#   inflating: images/validation/Class 1 Touch/827.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._827.jpg
#   inflating: images/validation/Class 1 Touch/67.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._67.jpg
#   inflating: images/validation/Class 1 Touch/85629.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85629.jpg
#   inflating: images/validation/Class 1 Touch/698.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._698.jpg
#   inflating: images/validation/Class 1 Touch/840.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._840.jpg
#   inflating: images/validation/Class 1 Touch/854.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._854.jpg
#   inflating: images/validation/Class 1 Touch/85615.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85615.jpg
#   inflating: images/validation/Class 1 Touch/28.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._28.jpg
#   inflating: images/validation/Class 1 Touch/868.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._868.jpg
#   inflating: images/validation/Class 1 Touch/85601.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85601.jpg
#   inflating: images/validation/Class 1 Touch/883.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._883.jpg
#   inflating: images/validation/Class 1 Touch/897.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._897.jpg
#   inflating: images/validation/Class 1 Touch/129.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._129.jpg
#   inflating: images/validation/Class 1 Touch/101.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._101.jpg
#   inflating: images/validation/Class 1 Touch/667.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._667.jpg
#   inflating: images/validation/Class 1 Touch/673.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._673.jpg
#   inflating: images/validation/Class 1 Touch/115.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._115.jpg
#   inflating: images/validation/Class 1 Touch/85359.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85359.jpg
#   inflating: images/validation/Class 1 Touch/85371.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85371.jpg
#   inflating: images/validation/Class 1 Touch/85417.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85417.jpg
#   inflating: images/validation/Class 1 Touch/85403.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85403.jpg
#   inflating: images/validation/Class 1 Touch/85365.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85365.jpg
#   inflating: images/validation/Class 1 Touch/85239.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85239.jpg
#   inflating: images/validation/Class 1 Touch/288.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._288.jpg
#   inflating: images/validation/Class 1 Touch/85563.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85563.jpg
#   inflating: images/validation/Class 1 Touch/85577.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85577.jpg
#   inflating: images/validation/Class 1 Touch/85588.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85588.jpg
#   inflating: images/validation/Class 1 Touch/277.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._277.jpg
#   inflating: images/validation/Class 1 Touch/263.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._263.jpg
#   inflating: images/validation/Class 1 Touch/934.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._934.jpg
#   inflating: images/validation/Class 1 Touch/920.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._920.jpg
#   inflating: images/validation/Class 1 Touch/908.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._908.jpg
#   inflating: images/validation/Class 1 Touch/713.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._713.jpg
#   inflating: images/validation/Class 1 Touch/707.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._707.jpg
#   inflating: images/validation/Class 1 Touch/706.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._706.jpg
#   inflating: images/validation/Class 1 Touch/712.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._712.jpg
#   inflating: images/validation/Class 1 Touch/909.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._909.jpg
#   inflating: images/validation/Class 1 Touch/921.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._921.jpg
#   inflating: images/validation/Class 1 Touch/935.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._935.jpg
#   inflating: images/validation/Class 1 Touch/262.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._262.jpg
#   inflating: images/validation/Class 1 Touch/276.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._276.jpg
#   inflating: images/validation/Class 1 Touch/85589.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85589.jpg
#   inflating: images/validation/Class 1 Touch/85576.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85576.jpg
#   inflating: images/validation/Class 1 Touch/85562.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85562.jpg
#   inflating: images/validation/Class 1 Touch/85238.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85238.jpg
#   inflating: images/validation/Class 1 Touch/289.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._289.jpg
#   inflating: images/validation/Class 1 Touch/85402.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85402.jpg
#   inflating: images/validation/Class 1 Touch/85364.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85364.jpg
#   inflating: images/validation/Class 1 Touch/85370.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85370.jpg
#   inflating: images/validation/Class 1 Touch/85416.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85416.jpg
#   inflating: images/validation/Class 1 Touch/85358.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85358.jpg
#   inflating: images/validation/Class 1 Touch/672.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._672.jpg
#   inflating: images/validation/Class 1 Touch/114.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._114.jpg
#   inflating: images/validation/Class 1 Touch/100.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._100.jpg
#   inflating: images/validation/Class 1 Touch/666.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._666.jpg
#   inflating: images/validation/Class 1 Touch/896.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._896.jpg
#   inflating: images/validation/Class 1 Touch/128.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._128.jpg
#   inflating: images/validation/Class 1 Touch/882.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._882.jpg
#   inflating: images/validation/Class 1 Touch/869.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._869.jpg
#   inflating: images/validation/Class 1 Touch/29.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._29.jpg
#   inflating: images/validation/Class 1 Touch/85600.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85600.jpg
#   inflating: images/validation/Class 1 Touch/85614.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85614.jpg
#   inflating: images/validation/Class 1 Touch/855.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._855.jpg
#   inflating: images/validation/Class 1 Touch/15.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._15.jpg
#   inflating: images/validation/Class 1 Touch/85628.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85628.jpg
#   inflating: images/validation/Class 1 Touch/841.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._841.jpg
#   inflating: images/validation/Class 1 Touch/699.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._699.jpg
#   inflating: images/validation/Class 1 Touch/17.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._17.jpg
#   inflating: images/validation/Class 1 Touch/857.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._857.jpg
#   inflating: images/validation/Class 1 Touch/843.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._843.jpg
#   inflating: images/validation/Class 1 Touch/85602.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85602.jpg
#   inflating: images/validation/Class 1 Touch/85616.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85616.jpg
#   inflating: images/validation/Class 1 Touch/894.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._894.jpg
#   inflating: images/validation/Class 1 Touch/880.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._880.jpg
#   inflating: images/validation/Class 1 Touch/658.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._658.jpg
#   inflating: images/validation/Class 1 Touch/116.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._116.jpg
#   inflating: images/validation/Class 1 Touch/670.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._670.jpg
#   inflating: images/validation/Class 1 Touch/664.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._664.jpg
#   inflating: images/validation/Class 1 Touch/102.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._102.jpg
#   inflating: images/validation/Class 1 Touch/85428.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85428.jpg
#   inflating: images/validation/Class 1 Touch/85366.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85366.jpg
#   inflating: images/validation/Class 1 Touch/85400.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85400.jpg
#   inflating: images/validation/Class 1 Touch/85414.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85414.jpg
#   inflating: images/validation/Class 1 Touch/85372.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85372.jpg
#   inflating: images/validation/Class 1 Touch/85399.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85399.jpg
#   inflating: images/validation/Class 1 Touch/85548.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85548.jpg
#   inflating: images/validation/Class 1 Touch/82233.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._82233.jpg
#   inflating: images/validation/Class 1 Touch/85574.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85574.jpg
#   inflating: images/validation/Class 1 Touch/85560.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._85560.jpg
#   inflating: images/validation/Class 1 Touch/248.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._248.jpg
#   inflating: images/validation/Class 1 Touch/260.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._260.jpg
#   inflating: images/validation/Class 1 Touch/274.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._274.jpg
#   inflating: images/validation/Class 1 Touch/923.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._923.jpg
#   inflating: images/validation/Class 1 Touch/937.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._937.jpg
#   inflating: images/validation/Class 1 Touch/738.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._738.jpg
#   inflating: images/validation/Class 1 Touch/704.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._704.jpg
#   inflating: images/validation/Class 1 Touch/710.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._710.jpg
#   inflating: images/validation/Class 1 Touch/711.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._711.jpg
#   inflating: images/validation/Class 1 Touch/705.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._705.jpg
#   inflating: images/validation/Class 1 Touch/739.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._739.jpg
#   inflating: images/validation/Class 1 Touch/936.jpg
#   inflating: __MACOSX/images/validation/Class 1 Touch/._936.jpg
#   inflating: images/validation/Class 1 Touch/922.jpg
# ...
#   inflating: images/validation/Class 2 No hands/106464.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106464.jpg
#   inflating: images/validation/Class 2 No hands/794.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._794.jpg
#   inflating: images/validation/Class 2 No hands/106458.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106458.jpg
#   inflating: images/validation/Class 2 No hands/743.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._743.jpg
#   inflating: images/validation/Class 2 No hands/757.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._757.jpg
#   inflating: images/validation/Class 2 No hands/756.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._756.jpg
#   inflating: images/validation/Class 2 No hands/742.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._742.jpg
#   inflating: images/validation/Class 2 No hands/106459.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106459.jpg
#   inflating: images/validation/Class 2 No hands/795.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._795.jpg
#   inflating: images/validation/Class 2 No hands/106465.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106465.jpg
#   inflating: images/validation/Class 2 No hands/781.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._781.jpg
#   inflating: images/validation/Class 2 No hands/106471.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106471.jpg
#   inflating: images/validation/Class 2 No hands/568.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._568.jpg
#   inflating: images/validation/Class 2 No hands/106698.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106698.jpg
#   inflating: images/validation/Class 2 No hands/232.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._232.jpg
#   inflating: images/validation/Class 2 No hands/554.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._554.jpg
#   inflating: images/validation/Class 2 No hands/540.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._540.jpg
#   inflating: images/validation/Class 2 No hands/226.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._226.jpg
#   inflating: images/validation/Class 2 No hands/106667.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106667.jpg
#   inflating: images/validation/Class 2 No hands/597.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._597.jpg
#   inflating: images/validation/Class 2 No hands/106673.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106673.jpg
#   inflating: images/validation/Class 2 No hands/583.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._583.jpg
#   inflating: images/validation/Class 2 No hands/102549.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._102549.jpg
#   inflating: images/validation/Class 2 No hands/106713.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106713.jpg
#   inflating: images/validation/Class 2 No hands/102575.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._102575.jpg
#   inflating: images/validation/Class 2 No hands/102561.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._102561.jpg
#   inflating: images/validation/Class 2 No hands/106707.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106707.jpg
#   inflating: images/validation/Class 2 No hands/86.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._86.jpg
#   inflating: images/validation/Class 2 No hands/178.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._178.jpg
#   inflating: images/validation/Class 2 No hands/92.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._92.jpg
#   inflating: images/validation/Class 2 No hands/622.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._622.jpg
#   inflating: images/validation/Class 2 No hands/144.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._144.jpg
#   inflating: images/validation/Class 2 No hands/150.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._150.jpg
#   inflating: images/validation/Class 2 No hands/636.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._636.jpg
#   inflating: images/validation/Class 2 No hands/805.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._805.jpg
#   inflating: images/validation/Class 2 No hands/45.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._45.jpg
#   inflating: images/validation/Class 2 No hands/3.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._3.jpg
#   inflating: images/validation/Class 2 No hands/811.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._811.jpg
#   inflating: images/validation/Class 2 No hands/106539.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106539.jpg
#   inflating: images/validation/Class 2 No hands/51.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._51.jpg
#   inflating: images/validation/Class 2 No hands/106511.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106511.jpg
#   inflating: images/validation/Class 2 No hands/839.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._839.jpg
#   inflating: images/validation/Class 2 No hands/79.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._79.jpg
#   inflating: images/validation/Class 2 No hands/187.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._187.jpg
#   inflating: images/validation/Class 2 No hands/193.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._193.jpg
#   inflating: images/validation/Class 2 No hands/106505.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106505.jpg
#   inflating: images/validation/Class 2 No hands/185.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._185.jpg
#   inflating: images/validation/Class 2 No hands/106513.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106513.jpg
#   inflating: images/validation/Class 2 No hands/106507.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106507.jpg
#   inflating: images/validation/Class 2 No hands/191.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._191.jpg
#   inflating: images/validation/Class 2 No hands/47.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._47.jpg
#   inflating: images/validation/Class 2 No hands/807.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._807.jpg
#   inflating: images/validation/Class 2 No hands/53.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._53.jpg
#   inflating: images/validation/Class 2 No hands/813.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._813.jpg
#   inflating: images/validation/Class 2 No hands/1.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._1.jpg
#   inflating: images/validation/Class 2 No hands/146.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._146.jpg
#   inflating: images/validation/Class 2 No hands/620.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._620.jpg
#   inflating: images/validation/Class 2 No hands/634.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._634.jpg
#   inflating: images/validation/Class 2 No hands/152.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._152.jpg
#   inflating: images/validation/Class 2 No hands/84.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._84.jpg
#   inflating: images/validation/Class 2 No hands/608.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._608.jpg
#   inflating: images/validation/Class 2 No hands/90.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._90.jpg
#   inflating: images/validation/Class 2 No hands/102577.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._102577.jpg
#   inflating: images/validation/Class 2 No hands/106711.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106711.jpg
#   inflating: images/validation/Class 2 No hands/106705.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106705.jpg
#   inflating: images/validation/Class 2 No hands/102563.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._102563.jpg
#   inflating: images/validation/Class 2 No hands/595.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._595.jpg
#   inflating: images/validation/Class 2 No hands/106665.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106665.jpg
#   inflating: images/validation/Class 2 No hands/581.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._581.jpg
#   inflating: images/validation/Class 2 No hands/106671.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106671.jpg
#   inflating: images/validation/Class 2 No hands/106659.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106659.jpg
#   inflating: images/validation/Class 2 No hands/556.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._556.jpg
#   inflating: images/validation/Class 2 No hands/230.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._230.jpg
#   inflating: images/validation/Class 2 No hands/224.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._224.jpg
#   inflating: images/validation/Class 2 No hands/542.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._542.jpg
#   inflating: images/validation/Class 2 No hands/218.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._218.jpg
#   inflating: images/validation/Class 2 No hands/106467.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106467.jpg
#   inflating: images/validation/Class 2 No hands/797.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._797.jpg
#   inflating: images/validation/Class 2 No hands/106473.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106473.jpg
#   inflating: images/validation/Class 2 No hands/783.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._783.jpg
#   inflating: images/validation/Class 2 No hands/106329.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106329.jpg
#   inflating: images/validation/Class 2 No hands/754.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._754.jpg
#   inflating: images/validation/Class 2 No hands/740.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._740.jpg
#   inflating: images/validation/Class 2 No hands/768.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._768.jpg
#   inflating: images/validation/Class 2 No hands/106498.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106498.jpg
#   inflating: images/validation/Class 2 No hands/106499.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106499.jpg
#   inflating: images/validation/Class 2 No hands/769.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._769.jpg
#   inflating: images/validation/Class 2 No hands/741.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._741.jpg
#   inflating: images/validation/Class 2 No hands/755.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._755.jpg
#   inflating: images/validation/Class 2 No hands/106328.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106328.jpg
#   inflating: images/validation/Class 2 No hands/782.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._782.jpg
#   inflating: images/validation/Class 2 No hands/106472.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106472.jpg
#   inflating: images/validation/Class 2 No hands/796.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._796.jpg
#   inflating: images/validation/Class 2 No hands/106466.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106466.jpg
#   inflating: images/validation/Class 2 No hands/219.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._219.jpg
#   inflating: images/validation/Class 2 No hands/225.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._225.jpg
#   inflating: images/validation/Class 2 No hands/543.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._543.jpg
#   inflating: images/validation/Class 2 No hands/557.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._557.jpg
#   inflating: images/validation/Class 2 No hands/231.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._231.jpg
#   inflating: images/validation/Class 2 No hands/106658.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106658.jpg
#   inflating: images/validation/Class 2 No hands/106670.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106670.jpg
#   inflating: images/validation/Class 2 No hands/580.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._580.jpg
#   inflating: images/validation/Class 2 No hands/106664.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106664.jpg
#   inflating: images/validation/Class 2 No hands/594.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._594.jpg
#   inflating: images/validation/Class 2 No hands/102562.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._102562.jpg
#   inflating: images/validation/Class 2 No hands/106704.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106704.jpg
#   inflating: images/validation/Class 2 No hands/106710.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106710.jpg
#   inflating: images/validation/Class 2 No hands/102576.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._102576.jpg
#   inflating: images/validation/Class 2 No hands/91.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._91.jpg
#   inflating: images/validation/Class 2 No hands/609.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._609.jpg
#   inflating: images/validation/Class 2 No hands/85.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._85.jpg
#   inflating: images/validation/Class 2 No hands/635.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._635.jpg
#   inflating: images/validation/Class 2 No hands/153.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._153.jpg
#   inflating: images/validation/Class 2 No hands/147.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._147.jpg
#   inflating: images/validation/Class 2 No hands/621.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._621.jpg
#   inflating: images/validation/Class 2 No hands/812.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._812.jpg
#   inflating: images/validation/Class 2 No hands/52.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._52.jpg
#   inflating: images/validation/Class 2 No hands/0.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._0.jpg
#   inflating: images/validation/Class 2 No hands/806.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._806.jpg
#   inflating: images/validation/Class 2 No hands/46.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._46.jpg
#   inflating: images/validation/Class 2 No hands/106506.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106506.jpg
#   inflating: images/validation/Class 2 No hands/190.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._190.jpg
#   inflating: images/validation/Class 2 No hands/184.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._184.jpg
#   inflating: images/validation/Class 2 No hands/106512.jpg
#   inflating: __MACOSX/images/validation/Class 2 No hands/._106512.jpg

# %% [markdown]
# ### Access the directory

# %%
import os

train_data_dir = 'images/train'
validation_data_dir = 'images/validation/'

# print all subjects in the train directory
subjects_in_train = os.listdir(train_data_dir)
print(subjects_in_train)
# Out:
# ['Class 3 No Touch w Hands', 'Class 1 Touch', 'Class 2 No hands']

# %% [markdown]
# ### Loading and Exploring the dataset

# %%
import cv2
# Function to load the image
def load_image(directory):
    images_path = []
    labels = []
    # access into each label folder and image inside that label
    for images_class in os.listdir(directory):
        for image_file in os.listdir(os.path.join(directory, images_class)):
            image_path = os.path.join(directory, images_class, image_file)
            image = cv2.imread(image_path, cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            images_path.append(image)
            labels.append(images_class)
    return images_path, labels


# Load images and labels from train and validation directories
train_images, train_labels = load_image(train_data_dir)
print("Train Image: ", len(train_images), "Labels: ", len(train_labels))
validation_images, validation_labels = load_image(validation_data_dir)
print("Validate Image: ", len(validation_images), "Labels: ", len(validation_labels))
# Out:
# Train Image:  15616 Labels:  15616
# Validate Image:  3479 Labels:  3479

# %% [markdown]
# ### Exploring the dataset

# %%
import pandas as pd

train = pd.DataFrame()
train['image'], train['label'] = load_image(train_data_dir)      # call the load_image function on train folder
# shuffle the dataset
train = train.sample(frac=1).reset_index(drop=True)
train
# Out:
#                                                    image  \
# 0      [[[106, 102, 91], [108, 104, 93], [111, 107, 9...
# 1      [[[164, 140, 114], [164, 140, 114], [164, 140,...
# 2      [[[208, 199, 202], [209, 200, 203], [208, 199,...
# 3      [[[156, 119, 64], [156, 119, 64], [158, 121, 6...
# 4      [[[124, 122, 99], [126, 124, 101], [127, 125, ...
# ...                                                  ...
# 15611  [[[142, 136, 114], [143, 137, 115], [144, 138,...
# 15612  [[[134, 149, 168], [133, 148, 167], [133, 148,...
# 15613  [[[135, 126, 119], [135, 126, 119], [136, 127,...
# 15614  [[[253, 255, 254], [253, 255, 254], [253, 255,...
# 15615  [[[153, 120, 69], [153, 120, 69], [153, 120, 6...
#
#                           label
# 0      Class 3 No Touch w Hands
# 1                 Class 1 Touch
# 2                 Class 1 Touch
# 3              Class 2 No hands
# 4                 Class 1 Touch
# ...                         ...
# 15611          Class 2 No hands
# 15612          Class 2 No hands
# 15613          Class 2 No hands
# 15614  Class 3 No Touch w Hands
# 15615          Class 2 No hands
#
# [15616 rows x 2 columns]

# %% [markdown]
# ### Visualize a few sample images from training set

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_images(images, labels, num_samples):
    # Get unique labels and initialize the plot counter
    class_names = np.unique(labels)
    plot_count = 1

    # Determine the total number of plot rows needed
    num_classes = len(class_names)
    fig = plt.figure(figsize=(10, 8))

    for class_name in class_names:
        # Find indices of images belonging to the current class
        class_indices = np.where(labels == class_name)[0][:num_samples]
        for idx in class_indices:
            # Create a subplot for each sample image
            ax = fig.add_subplot(num_classes, num_samples, plot_count)
            ax.imshow(images[idx], cmap='gray')
            ax.axis('off')  # Hide axes ticks
            ax.set_title(class_name, fontsize=10)
            plot_count += 1

    plt.tight_layout()
    plt.subplots_adjust(hspace=0.0, wspace=0.1)  # Adjust the space between plots
    plt.show()

# function call
plot_sample_images(train['image'], train['label'], num_samples=5)

# %% [markdown]
# ### Plotting the training set distribution

# %%
import plotly.express as px
import plotly.io as pio

# Calculate the count of images for each class in the training set
train_class_counts = {class_name: np.sum(train['label'] == class_name) for class_name in np.unique(train['label'])}

# Create a bar chart using a custom color sequence
fig = px.bar(
    x=list(train_class_counts.keys()),
    y=list(train_class_counts.values()),
    color=list(train_class_counts.keys()),
    color_discrete_sequence=px.colors.qualitative.Set2_r
)
fig.update_layout(
    title="Total samples for each class (Training set distribution)",
    xaxis_title="Label",
    yaxis_title="Count",
    width=800,
    height=350
)
fig.update_traces(texttemplate='%{y}', textposition='inside')  # Display count labels on the bars
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6f785c17-cbb9-49a5-925b-6177d7720b69" class="plotly-graph-div" style="height:350px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f785c17-cbb9-49a5-925b-6177d7720b69")) {                    Plotly.newPlot(                        "6f785c17-cbb9-49a5-925b-6177d7720b69",                        [{"alignmentgroup":"True","hovertemplate":"color=Class 1 Touch\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Class 1 Touch","marker":{"color":"rgb(179,179,179)","pattern":{"shape":""}},"name":"Class 1 Touch","offsetgroup":"Class 1 Touch","orientation":"v","showlegend":true,"textposition":"inside","x":["Class 1 Touch"],"xaxis":"x","y":[4642],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"color=Class 2 No hands\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Class 2 No hands","marker":{"color":"rgb(229,196,148)","pattern":{"shape":""}},"name":"Class 2 No hands","offsetgroup":"Class 2 No hands","orientation":"v","showlegend":true,"textposition":"inside","x":["Class 2 No hands"],"xaxis":"x","y":[6125],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"color=Class 3 No Touch w Hands\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Class 3 No Touch w Hands","marker":{"color":"rgb(255,217,47)","pattern":{"shape":""}},"name":"Class 3 No Touch w Hands","offsetgroup":"Class 3 No Touch w Hands","orientation":"v","showlegend":true,"textposition":"inside","x":["Class 3 No Touch w Hands"],"xaxis":"x","y":[4849],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %% [markdown]
# ### Processing to tensor and aumenting images for pretrained model
# - randomly transform, flip, rotate to increase the diversity
# - convert to tensor
# - normalize dataset
# - Changle color with brightness, contrast, saturation and hue

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torchvision.transforms as transforms
import torch
from torchvision.datasets import ImageFolder

# image augmentation, transform on RGB, and convert to tensor

train_transforms = transforms.Compose([
    transforms.CenterCrop(224), # to focus on center
    # transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1), shear=10), #images shift along 10% x/y axis
    transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally
    transforms.ColorJitter(brightness=0.2, contrast=0.3, saturation=0.4, hue=0.05),
    transforms.RandomRotation(20),  # Randomly rotate the image by 20 degrees
    transforms.ToTensor(),  # Converts the PIL Image (HxWxC) in the range [0, 255] to a tensor shape (CxHxW) in the range [0.0, 1.0]
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # derived these number from the ImageNet on RGB channel
])

val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %% [markdown]
# ### Load dataset to loader and set batch size to 32

# %%
# apply transform on dataset
train_set = ImageFolder(root=train_data_dir, transform=train_transforms)
validation_set = ImageFolder(root=validation_data_dir, transform=val_transforms)


# load data to loader
train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(validation_set, batch_size=64, shuffle=False)

# check the size after transfer to loader for Torch
print(f"Number of training samples: {len(train_set)}")
print(f"Number of validation samples: {len(validation_set)}")

# Check the shape of the first training image [channel, width, height]
train_x, train_y = train_set[0]
print(f"Shape of first training images in first batch : {train_x.shape}")
print(f"first label images : {train_y}")


for batch in train_loader:
    images, labels = batch
    print(f"Shape of first training images in first batch: {images.shape}")  # [batch_size, channels, height, width]
    print(f"Check type of input and label", type(images), type(images))
    break
# Out:
# Number of training samples: 15616
# Number of validation samples: 3479
# Shape of first training images in first batch : torch.Size([3, 224, 224])
# first label images : 0
# Shape of first training images in first batch: torch.Size([64, 3, 224, 224])
# Check type of input and label <class 'torch.Tensor'> <class 'torch.Tensor'>

# %% [markdown]
# ## CNN model
# ### Bulding Deep Learning model with 4-layer of convolutional neural network and 2 fully connected layer

# %%
# mport pytorch library and modules
import torch
import torch.nn as nn
import torch.nn.functional as F
# import torch.optim as optim
from torch.optim import Adam
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, BatchNorm2d, BatchNorm1d, Dropout, AdaptiveAvgPool2d

# %% [markdown]
# ### Architecture of Deep CNN model
# - 4 convolutional layes to extract features from images with 64 5x5 filters, 128 5x5 filters, 256 5x5 filters, 512 5x5 filters
#     - Each convolutional layer: stride 1, batch normalization, dropout rate 0.25, max-pooling and ReLU
# - flattening step
# - Average global pooling
# - 1 fully connected dense layers
#     - 512 neuron in the input layers and 512 neuron of in hidden layers
#     - batch norm, dropout is 0.5, ReLu on each layer
#
# - Channel for Convolutional layer should be 3 because this is color image

# %%
class convnet(nn.Module):
    # constructor initialize instances of class
    def __init__(self, num_classes):
        super(convnet, self).__init__()         # Call the init method of nn.Module

        # defining 2D convolutional layers by Squential for cleaner look
        self.cnn_layers = Sequential(
            # stride=1 paddind = 0 by default
            # first block:
            Conv2d(3, 64, kernel_size = 3, padding = 1),  # dot product of input and kernel to complete 1 pixel at a time: stride
            BatchNorm2d(64),                                        # improves the performance and stability of NNs with unit
            ReLU(),                                                 # non linear func to squash linear combination into 0 and 1
            Dropout(p=0.25),                                         # reduces overfitting/prevent not relying on one node in the layer too much
            MaxPool2d(kernel_size=2),                               # reduce dimension but still obtain important data

            # second block
            Conv2d(64, 128, kernel_size = 5, padding = 1),
            BatchNorm2d(128),
            ReLU(),
            Dropout(p=0.25),
            MaxPool2d(kernel_size=2),

            # third block
            Conv2d(128, 512, kernel_size = 3, padding = 1),
            BatchNorm2d(512),
            ReLU(),
            Dropout(p=0.25),
            MaxPool2d(kernel_size=2),

            # fourth block
            Conv2d(512, 512, kernel_size = 3, padding = 1),
            BatchNorm2d(512),
            ReLU(),
            Dropout(p=0.25),
            MaxPool2d(kernel_size=2),
        )


        # definind 2 fully connected layer (multi layers nn)
        self.linear_layers = Sequential(

            # first fully connected layer  (input to hidden1)
            Linear(512 * 13 * 13, 256),       # input size of flatten layer: 256 with 512 hidden node in first hidden layer
            BatchNorm1d(256),
            ReLU(),
            Dropout(p=0.5),

            # second fully connected layer  (hidden to hidden 2)
            Linear(256, 512),                 # 512 hidden node in second hidden layer
            BatchNorm1d(512),
            ReLU(),
            Dropout(p=0.5),

            # hidden 2 to output
            Linear(512, num_classes)
        )

    def forward(self, x):
        # forward pass through cnn and linear layers
        z1 = self.cnn_layers(x)
        # print(f"Before flattening: {z1.size()}")  # Debug print

        # Adding Global Average Pooling
        # z1 = self.global_avg_pool(z1)
        z1 = z1.view(z1.size(0), -1)  # Flatten the output of conv layers
        # output flatten of convo layer is input of fully connected layer
        z2 = self.linear_layers(z1)

        # return F.softmax(z2, dim = 1)
        return z2

# %% [markdown]
# ### debug to check the size of output of flatten layer before feed in FC layers
# - if using AdaptiveAvgPool, dont need to adjust the input size for the first fully connected layer bc it flatten the tensor to 1D for each vector of size 512 for each image in the batch

# %%
model = convnet(num_classes=3)  # instantiate the instance of class

# Create input with the size of input images (batch_size, channels, height, width)
check_input = torch.randn(1, 3, 224, 224)

check_input = model.cnn_layers(check_input)
# Print the resulting size
print(check_input.size())
# Out:
# torch.Size([1, 512, 13, 13])

# %% [markdown]
# ### define the opmizier and loss function for model
#
# - For objective function in supervise learning task: goal is to minimize this function (distance between predict and actual)
#     - Loss function: using cross entropy because this is classification problems
#     - Optimization: Using Adam with learning rate at 0.01, decent weight regulation at 1e-5

# %%
# Instantiate the model
num_classes = 3
model = convnet(num_classes)

# defining the optimizer: Adam with regulation to prevent overfitting
optimizer = Adam(model.parameters(), lr = 0.001, weight_decay=1e-6)
# defining the loss function
criterion = CrossEntropyLoss()
print(model)
# Out:
# convnet(
#   (cnn_layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): Dropout(p=0.25, inplace=False)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): Dropout(p=0.25, inplace=False)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): Dropout(p=0.25, inplace=False)
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=86528, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=512, bias=True)
#     (5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Add to device

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
model = model.to(device)
# Out:
# cuda

# %%
# use for function call during the training process to cal + print the accuracy in each epoch
def calculate_accuracy(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    predictions = 0
    total_samples = 0
    true_labels = []
    pred_labels = []

    with torch.no_grad():  # No track gradients
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            y_pred = torch.argmax(outputs, dim=1)                   # Use argmax to get predictions: highest prob

            # accuracy metric as the number of correctly predicted results / total numbe of samples
            predictions += torch.sum(y_pred == labels).item()
            total_samples += labels.size(0)                         # length of tensor at first dimension

            # store for confusion matrix from scikit-learn in numpy form. CPU for comparable with library scikit-learn
            pred_labels.extend(y_pred.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    total_acc = predictions / total_samples

    return total_acc, true_labels, pred_labels

# %% [markdown]
# ### Training and Evaluate the model on both validation

# %%
def fit(epochs):
    # patience=10
    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    # for saving the best value of each epoch
    best_val_loss = float('inf')
    epochs_early_stop = 0  # Track epochs with no improvement for early stop

    for epoch in range(epochs):

        # -------- Calculate training acc for the previous epoch--------
        train_accuracy, _, _ = calculate_accuracy(model, train_loader)
        train_acc.append(train_accuracy)

        # --------Training loss--------
        tr_loss = 0
        # set model in training mode
        model.train()
        for inputs, labels in train_loader:
            # load dataset to device
            inputs, labels = inputs.to(device), labels.to(device)

            # clear the gradient of model parameters
            optimizer.zero_grad()

            # Forward pass: prediction for training and validation set from the input
            train_output = model(inputs)                            # output from predict on training set
            train_loss = criterion(train_output, labels)            # calculate the loss between output and ground truth with cross entropy

            # Backward pass and optimize: to updated the weight of all model parameters to improve the loss
            train_loss.backward()                                   # backpropagate
            optimizer.step()                                        # gradient decent to update paramter
            tr_loss += train_loss.item()                            # extract and keep track loss each epochs: .item(): is single-element tensor convert to float format

        avg_train_loss = tr_loss/ len(train_loader)                 # divide accumulated loss by the number of batches
        train_losses.append(avg_train_loss)


        # --------Validation loss--------
        validate_loss = 0
        model.eval()
        with torch.no_grad():                                       # no gradient on validation
            for inputs, labels in val_loader:
                # load dataset to device
                inputs, labels = inputs.to(device), labels.to(device)

                # Forward pass on validation. No backward on validation
                val_output = model(inputs)
                val_loss = criterion(val_output, labels)
                validate_loss += val_loss.item()                            # keep track of loss each epochs

            avg_val_loss = validate_loss/len(val_loader)

            # Check if this is the best model so far
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model_state = model.state_dict() # save the best model state
                torch.save(model.state_dict(), 'best_model_state3.pth')

            val_losses.append(avg_val_loss)                                 # store best loss value

        # Calculate validation accuracy each epoch
        val_accuracy, _, _ = calculate_accuracy(model, val_loader)
        val_acc.append(val_accuracy)

        # if epoch % 2 == 0:
        print(f'Epoch {epoch + 1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f} | Train Acc: {train_accuracy:.4f} | Val Acc: {val_accuracy:.4f}  ')

    return train_losses, val_losses, train_acc, val_acc, best_model_state

# %%
num_epochs = 20
train_loss, val_loss, train_acc, val_acc, best_model_state = fit(num_epochs)
# Out:
# Epoch 1/20 | Train Loss: 0.1472 | Val Loss: 1.1665 | Train Acc: 0.7014 | Val Acc: 0.6496
# Epoch 2/20 | Train Loss: 0.1252 | Val Loss: 1.1973 | Train Acc: 0.7428 | Val Acc: 0.5847
# Epoch 3/20 | Train Loss: 0.0891 | Val Loss: 1.3137 | Train Acc: 0.8213 | Val Acc: 0.6528
# Epoch 4/20 | Train Loss: 0.0921 | Val Loss: 1.5663 | Train Acc: 0.8742 | Val Acc: 0.5366
# Epoch 5/20 | Train Loss: 0.0733 | Val Loss: 1.2826 | Train Acc: 0.7771 | Val Acc: 0.6223
# Epoch 6/20 | Train Loss: 0.0796 | Val Loss: 1.4726 | Train Acc: 0.8866 | Val Acc: 0.5203
# Epoch 7/20 | Train Loss: 0.0592 | Val Loss: 1.6323 | Train Acc: 0.8168 | Val Acc: 0.5763
# Epoch 8/20 | Train Loss: 0.0665 | Val Loss: 1.5428 | Train Acc: 0.8945 | Val Acc: 0.5596
# Epoch 9/20 | Train Loss: 0.0560 | Val Loss: 1.3068 | Train Acc: 0.8730 | Val Acc: 0.6166
# Epoch 10/20 | Train Loss: 0.0555 | Val Loss: 1.4397 | Train Acc: 0.9407 | Val Acc: 0.5680
# Epoch 11/20 | Train Loss: 0.0584 | Val Loss: 1.3156 | Train Acc: 0.8494 | Val Acc: 0.6099
# Epoch 12/20 | Train Loss: 0.0477 | Val Loss: 1.1638 | Train Acc: 0.9317 | Val Acc: 0.6792
# Epoch 13/20 | Train Loss: 0.0446 | Val Loss: 1.3370 | Train Acc: 0.9348 | Val Acc: 0.6223
# Epoch 14/20 | Train Loss: 0.0476 | Val Loss: 1.5087 | Train Acc: 0.9591 | Val Acc: 0.6016
# Epoch 15/20 | Train Loss: 0.0483 | Val Loss: 1.0927 | Train Acc: 0.8763 | Val Acc: 0.6959
# Epoch 16/20 | Train Loss: 0.0491 | Val Loss: 1.4860 | Train Acc: 0.8886 | Val Acc: 0.6042
# Epoch 17/20 | Train Loss: 0.0410 | Val Loss: 1.0366 | Train Acc: 0.8414 | Val Acc: 0.6740
# Epoch 18/20 | Train Loss: 0.0440 | Val Loss: 1.1521 | Train Acc: 0.9714 | Val Acc: 0.6551
# Epoch 19/20 | Train Loss: 0.0441 | Val Loss: 1.4468 | Train Acc: 0.9267 | Val Acc: 0.6025
# Epoch 20/20 | Train Loss: 0.0384 | Val Loss: 1.1329 | Train Acc: 0.8866 | Val Acc: 0.6815

# %% [markdown]
# ### The the loss curve of train/validation

# %%
import plotly.graph_objects as graph
# pio.renderers

fig = graph.Figure()

# the training loss
fig.add_trace(graph.Scatter(y=train_loss, mode='lines', name='Training Loss'))
# the validation loss
fig.add_trace(graph.Scatter(y=val_loss, mode='lines', name='Validation Loss'))
# Update the layout with titles and axis labels
fig.update_layout(title='Training and Validation Loss over Epochs',
                  xaxis_title='Epoch',
                  yaxis_title='Loss',
                  width=900,
                  height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c3351143-bd08-4043-ba45-09c1373b87b8" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3351143-bd08-4043-ba45-09c1373b87b8")) {                    Plotly.newPlot(                        "c3351143-bd08-4043-ba45-09c1373b87b8",                        [{"mode":"lines","name":"Training Loss","y":[0.14716988094303696,0.12521779565445956,0.08906914620492302,0.09211389403065025,0.0733085272501635,0.07964856280242932,0.05923247355662408,0.0665001961551454,0.05596112809430227,0.05552335617850061,0.05839434893015528,0.04769994501600836,0.04457282196715108,0.04763677330844135,0.04830187180491745,0.04908641252655261,0.04103400516891508,0.04398505033192332,0.0441232431364116,0.03837384506139225],"type":"scatter"},{"mode":"lines","name":"Validation Loss","y":[1.1665247089081359,1.1972853348505768,1.313743932096457,1.5663150695819323,1.2826100253718322,1.4726064288491298,1.6323004142042588,1.5428341830424457,1.306773766364098,1.4396672312175558,1.315617955171249,1.163800361466499,1.3369980542253788,1.5086606238528144,1.092680813588694,1.4859995352433708,1.036595945267684,1.1520805556364146,1.44680737959094,1.1328529864292993],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern ...

# %% [markdown]
# ### The accuracy curve

# %%
fig = graph.Figure()

# the training loss
fig.add_trace(graph.Scatter(y=train_acc, mode='lines', name='Training Accuracy'))
# the validation loss
fig.add_trace(graph.Scatter(y=val_acc, mode='lines', name='Validation Accuracy'))
# Update the layout with titles and axis labels
fig.update_layout(title='Training and Validation Accuracy over Epochs',
                  xaxis_title='Epoch',
                  yaxis_title='Accuracy',
                  width=900,
                  height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="33fa4550-dc8f-462a-b5b0-557ed0c035ba" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33fa4550-dc8f-462a-b5b0-557ed0c035ba")) {                    Plotly.newPlot(                        "33fa4550-dc8f-462a-b5b0-557ed0c035ba",                        [{"mode":"lines","name":"Training Accuracy","y":[0.7013960040983607,0.742827868852459,0.8212730532786885,0.8741675204918032,0.7770876024590164,0.8865906762295082,0.8167904713114754,0.89453125,0.8730148565573771,0.9407018442622951,0.8494492827868853,0.9317366803278688,0.9348104508196722,0.9591444672131147,0.876280737704918,0.8885758196721312,0.8414446721311475,0.9714395491803278,0.9267418032786885,0.8865906762295082],"type":"scatter"},{"mode":"lines","name":"Validation Accuracy","y":[0.64961195745904,0.584650761713136,0.6527737855705662,0.5366484622017821,0.6223052601322219,0.5202644438056913,0.5763150330554757,0.5596435757401552,0.6165564817476287,0.5679793043978154,0.6099453866053464,0.6792181661396953,0.6223052601322219,0.6016096579476862,0.6958896234550158,0.604196608220753,0.6740442655935613,0.6550732969244035,0.6024719747053751,0.6815176774935326],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":" ...

# %% [markdown]
# ### Overall accuracy

# %%
train_accuracy, train_true_labels, train_pred_labels = calculate_accuracy(model, train_loader)
val_accuracy, val_true_labels, val_pred_labels = calculate_accuracy(model, val_loader)


print(f'Train Accuracy: {train_accuracy:.4f}')
print(f'Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Train Accuracy: 0.9423
# Validation Accuracy: 0.6815

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


class_names = np.unique(train['label'])

# Generate confusion matrix
conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot confusion matrix with class names
plt.figure(figsize=(12, 6))
sns.heatmap(conf_matrix_normalized, annot=True, cmap="Blues", fmt=".2f", cbar=True,
            xticklabels=class_names, yticklabels=class_names)

plt.title("Normalized confusion matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
